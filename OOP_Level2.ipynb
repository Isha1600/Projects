# %% [markdown]
# <a href="https://colab.research.google.com/github/Isha1600/Python_Projects_Portfolio/blob/main/OOP_Level2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Car:
    def __init__(self, brand, speed):
        self.brand = brand
        self.speed = speed

    def increase_speed(self, amount):
        if amount > 0:
            self.speed += amount

    def decrease_speed(self, amount):
        if amount > 0 and self.speed - amount >= 0:
            self.speed -= amount

    def display(self):
        print(f"{self.brand} running at {self.speed} km/h")

# %%
class StudentManager:
    def __init__(self):
        self.students = []

    def add_student(self, name, marks):
        student = Student(name, marks)
        self.students.append(student)

    def view_students(self):
        for student in self.students:
            student.display()

    def show_passed_students(self):
        print("Passed Students:")
        for student in self.students:
            if student.is_pass():
                student.display()

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def display(self):
        print(f"{self.name} - {self.marks}")

    def is_pass(self):
        return self.marks >= 40

# %%
manager = StudentManager()
manager.add_student("Alice", 85)
manager.add_student("Bob", 30)
manager.add_student("Charlie", 60)
manager.add_student("David", 40)

manager.show_passed_students()
# Out:
# Passed Students:
# Alice - 85
# Charlie - 60
# David - 40
